# %% [markdown]
# # Web scrapping
#
# Szymon Dziubak

# %% [markdown]
# Jeżeli chcemy pobrać dane z jakiejś strony internetowej to przede wszystkim powinniśmy sprawdzić, czy nie istnieje API, które te dane udostępnia. <br>
# Jeżeli sprawdziliśmy, że API nie ma (a część stron internetowych i portali takie API ma, np. GUS, Facebook, Twitter, Allegro itd.) to możemy odwołać się do kodu HTML strony internetowej, żeby zeskrobać dane.

# %% [markdown]
# W pythonie istnieje biblioteka Beautiful Soup, która umożliwia skrobanie danych. Działa następująco:
# 1. Wysyamy zapytanie do strony internetowej i w odpowiedzi otrzymujemy kod HTML.
# 2. Parsujemy kod HTML - przetwarzamy go w ten sposób, aby uzyskać aby był on gotowy do przetworzenia.
# 3. Nawigujemy do interesujących nas elementów czyli do danych zawartych w kodzie HTML.

# %%
#!pip install requests
#!pip install html5lib
#!pip install bs4

# %%
#pobieramy dane ze strony internetowej

import requests
url = "https://www.onet.pl/"
r = requests.get(url)
print(r.content)
# Out:
# b'<!DOCTYPE html><html lang="pl" class="device-bot"><head><meta charset="utf-8"><link rel="canonical" href="https://www.onet.pl"><link rel="preload" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Regular.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link rel="preload" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Medium.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link rel="preload" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Bold.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link rel="preload" href="https://ocdn.eu/onetmobilemainpage/icofont/i34/onetsg.woff2" as="font" type="font/woff2" crossorigin="anonymous"><link rel="preload" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Bold-Cyrillic.woff2" as="font" type="font/woff2" crossorigin="anonymous"><script id="InlineScript-polyfills">(function () {\n          /* eslint-disable */\n          function getLocalStoragePolyfill() {\n            var instance = {};\n\n            function set(type, value) {\n              instance[type] = value;\n            }\n\n            function get(type, def) {\n              return instance[type] || def || null;\n            }\n\n            function clear() {\n              for (var key in instance) {\n                delete instance[key];\n              }\n            }\n\n            return {\n              get: get,\n              set: set,\n              clear: clear\n            };\n          }\n\n          var localStoragePolyfill = getLocalStoragePolyfill();\n\n          var checkLocalStorage = function () {\n            try {\n              window.localStorage.setItem(\'a\', \'b\');\n              window.localStorage.removeItem(\'a\');\n              return true;\n            } catch (e) {\n              return false;\n            }\n          };\n\n          if (!checkLocalStorage()) {\n            window.localStorage = {};\n            window.localStorage.getItem = localStoragePolyfill.get;\n            window.localStorage.setItem = localStoragePolyfill.set;\n\n            window.localStorage.removeItem = function (key) {\n              localStoragePolyfill.set(key, null);\n            };\n\n            window.localStorage.clear = localStoragePolyfill.clear;\n\n            window.localStorage.key = function () {\n              return null;\n            };\n          }\n          /* eslint-enable */\n\n        })({})</script><script id="InlineScript-onetAds">(function (props) {\n          window.onetAds = props.adsConfig;\n          const drlu = window.location.hash.match(/#rlu-(\\d+)/);\n\n          if (drlu && typeof drlu[1] !== \'undefined\') {\n            window.onetAds.keyvalues = window.onetAds.keyvalues || {};\n            window.onetAds.keyvalues.drlu = drlu[1];\n          }\n        })({"adsConfig":{"target":"GLOWNA/NOWASG","dv":"www","DV":"www","adsNoBanner":false,"gemius":"bPo6D0bzSxcue3osfkZZIJaE.l0RyeOgSEhsufRYys3.W7","no_gemius":1,"kropka":{"DG":"id=bPo6D0bzSxcue3osfkZZIJaE.l0RyeOgSEhsufRYys3.W7","DC":"BETA","XX":"dev-env","NA":null},"keywords":["V2021","ONET3D_2I","ONET3"],"lazy":true,"lazyPercentage":150,"mobile":0,"async":1,"cmd":[]}})</script><script id="InlineScript-dataLayer">(function (props) {\n          window.dataLayer = window.dataLayer || [];\n          window.dataLayer.push(props.dataLayer);\n        })({"dataLayer":{"DV":"www","ucsVariant":"BETA"}})</script><script id="InlineScript-paywallConfig">(function (props) {\n          /* eslint-disable */\n          window.paywall = window.paywall || {};\n\n          if (!window.paywall.config) {\n            window.paywall.config = props.config;\n          }\n\n          window.openLoginLayer = () => {\n            window.dispatchEvent(new Event(\'openLoginLayer\'));\n          };\n\n          window.logoutUser = () => {\n            window.dispatchEvent(new Event(\'logoutUser\'));\n          };\n\n          window.paywall.config.controlAuthorisatio ...

# %%
#parsujemy html - tworzymy strukture

from bs4 import BeautifulSoup
  
url = "https://www.onet.pl/"
r = requests.get(url) #wysyłamy zapytanie do strony
soup = BeautifulSoup(r.content, 'html5lib') # parser, html5lib bo mamy plik html
print(soup.prettify()) #ładne wyświetlenie
# Out:
# <!DOCTYPE html>
# <html class="device-bot" lang="pl">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.onet.pl" rel="canonical"/>
#   <link as="font" crossorigin="anonymous" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Medium.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://ocdn.eu/onetmobilemainpage/icofont/i34/onetsg.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://ocdn.eu/onetmobilemainpage/firafonts/p06/FiraSans-Bold-Cyrillic.woff2" rel="preload" type="font/woff2"/>
#   <script id="InlineScript-polyfills">
#    (function () {
#           /* eslint-disable */
#           function getLocalStoragePolyfill() {
#             var instance = {};
#
#             function set(type, value) {
#               instance[type] = value;
#             }
#
#             function get(type, def) {
#               return instance[type] || def || null;
#             }
#
#             function clear() {
#               for (var key in instance) {
#                 delete instance[key];
#               }
#             }
#
#             return {
#               get: get,
#               set: set,
#               clear: clear
#             };
#           }
#
#           var localStoragePolyfill = getLocalStoragePolyfill();
#
#           var checkLocalStorage = function () {
#             try {
#               window.localStorage.setItem('a', 'b');
#               window.localStorage.removeItem('a');
#               return true;
#             } catch (e) {
#               return false;
#             }
#           };
#
#           if (!checkLocalStorage()) {
#             window.localStorage = {};
#             window.localStorage.getItem = localStoragePolyfill.get;
#             window.localStorage.setItem = localStoragePolyfill.set;
#
#             window.localStorage.removeItem = function (key) {
#               localStoragePolyfill.set(key, null);
#             };
#
#             window.localStorage.clear = localStoragePolyfill.clear;
#
#             window.localStorage.key = function () {
#               return null;
#             };
#           }
#           /* eslint-enable */
#
#         })({})
#   </script>
#   <script id="InlineScript-onetAds">
#    (function (props) {
#           window.onetAds = props.adsConfig;
#           const drlu = window.location.hash.match(/#rlu-(\d+)/);
#
#           if (drlu && typeof drlu[1] !== 'undefined') {
#             window.onetAds.keyvalues = window.onetAds.keyvalues || {};
#             window.onetAds.keyvalues.drlu = drlu[1];
#           }
#         })({"adsConfig":{"target":"GLOWNA/NOWASG","dv":"www","DV":"www","adsNoBanner":false,"gemius":"bPo6D0bzSxcue3osfkZZIJaE.l0RyeOgSEhsufRYys3.W7","no_gemius":1,"kropka":{"DG":"id=bPo6D0bzSxcue3osfkZZIJaE.l0RyeOgSEhsufRYys3.W7","DC":"BETA","XX":"dev-env","NA":null},"keywords":["V2021","ONET3D_2I","ONET3"],"lazy":true,"lazyPercentage":150,"mobile":0,"async":1,"cmd":[]}})
#   </script>
#   <script id="InlineScript-dataLayer">
#    (function (props) {
#           window.dataLayer = window.dataLayer || [];
#           window.dataLayer.push(props.dataLayer);
#         })({"dataLayer":{"DV":"www","ucsVariant":"BETA"}})
#   </script>
#   <script id="InlineScript-paywallConfig">
#    (function (props) {
#           /* eslint-disable */
#           window.paywall = window.paywall || {};
#
#           if (!window.paywall.config) {
#             window.paywall.config = props.config;
#           }
#
#           window.openLoginLayer = () => {
#             window.dispatchEvent(new Event('openLoginLayer'));
#           };
#
#           window.logoutUser = () => {
#             window.dispatchEvent(new Event('logoutUser'));
#           };
#
#           window.paywall.config.controlAuthorisation = true;
#           window.paywall.config.loginMethod = window.openLoginLayer;
#           window.paywall.config.registerMethod = window.openLoginLayer;
#           window.paywall.config.logoutMethod = window.logoutUser;
#           let canReload = document.cookie.indexOf('premusr=1') === -1;
#           document.addEventListener('paywall.premusr.removed', () => {
#             canReload = true;
#           });
#           document.addEventListener('paywall.premusr.created', () => {
#             const isPremium = document.cookie.indexOf('premusr=1') !== -1;
#
#             if (canReload && isPremium) {
#               window.location.reload();
#             }
#           });
#           /* eslint-enable */
#         })({"config":{"env":"prod","tenant":"onet","aid":"soetsSSfpe","gaAnalytics":true,"schemaOrg":"Onet - Jesteś na bieżąco","kontoDomain":"konto.onet.pl","premiumContainerId":"contentPremium","clientId":"","contentSection":null,"autoLoadPiano":false,"autoLoadConfig":false,"tags":["tp_page_hp"]}})
#   </script>
#   <script id="InlineScript-undefined">
#    (function () {
#         /* eslint-disable */
#         var region;
#
#         try {
#           region = localStorage.getItem('regional:feed-codename').toUpperCase();
#         } catch (e) {}
#
#         region = region || 'WARSZAWA';
#
#         if (region && window.onetAds.keywords) {
#           window.onetAds.keywords.push(region);
#         }
#         /* eslint-enable */
#
#       })({})
#   </script>
#   <script id="InlineScript-undefined">
#    (function () {
#       /* eslint-disable */
#       window.nsglib = window.nsglib || {};
#
#       window.nsglib.setMargin = function () {
#         /* empty func */
#       };
#
#       window.nsglib.onMarginChange = function () {
#         /* empty func */
#       };
#
#       window.nsglib.getHeaderSwitchHeight = function () {
#         /* empty func */
#       };
#
#       window.nsglib.setHeaderSwitchHeight = function () {
#         /* empty func */
#       };
#
#       window.nsglibCommon = {
#         playerSwitcher: {
#           disablePlayers: function () {
#             window.Event && window.dispatchEvent && window.dispatchEvent(new window.Event('disableHomePagePlayers'));
#           },
#           enablePlayers: function () {
#             window.Event && window.dispatchEvent && window.dispatchEvent(new window.Event('enableHomePagePlayers'));
#           }
#         }
#       };
#       /* eslint-enable */
#     })({})
#   </script>
#   <title>
#    Onet – Jesteś na bieżąco
#   </title>
#   <meta content="Onet: codzienne źródło informacji milionów Polaków - wiadomości z kraju i ze świata 24/7, pogoda, sport, biznes, moto, rozrywka. Bądź na bieżąco z Onet!" name="description"/>
#   <meta content="width=1280" name="viewport"/>
#   <link as="image" href="https://ocdn.eu/omp3-images-transforms/1/8jtk9lGaHR0cHM6Ly9vY2RuLmV1L3B1bHNjbXMvTURBXy81ZmRlZjFiYi00NzZjLTQ1N2EtODFjYS1kNTM4YmY2ZmVlZGEuanBlZ5OVA8xSAM0EWs0CdpMFzQJszQEalQfZMi9wdWxzY21zL01EQV8vMjc0YzFkNjQ2NzA4MmMzZTZkZmU5ZDA5ZjRhNmRmNmIucG5nAMIA3gABoTAF" rel="preload" type="image/webp"/>
#   <meta content="18" name="next-head-count"/>
#   <link href="https://ocdn.eu" rel="dns-prefetch"/>
#   <link href="https://static.onet.pl" rel="dns-prefetch"/>
#   <link href="https://recommendations-onet.aureus.ringpublishing.com" rel="dns-prefetch"/>
#   <link href="https://csr.onet.pl" rel="dns-prefetch"/>
#   <link href="https://events.ocdn.eu" rel="dns-prefetch"/>
#   <link href="https://onet.hit.gemius.pl" rel="dns-prefetch"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#ffffff" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Onet" name="apple-mobile-web-app-title"/>
#   <meta content="IE=edge" httpequiv="X-UA-Compatible"/>
#   <script>
#    /* <![CDATA[ */ ringDataLayer = {"context":{"variant":{"accelerator":"d3d3Lm9uZXQucGw6OkFQUk9EXzNfMl8w"}}}; /* ]]> */
#   </script>
#   <script>
#    /* <![CDATA[ */ accConf = {"rum":{"tid":"EA-1746213","boot":"disable","cookieInfo":0,"pageType":"HTML"},"events":{"endpointPaths":["/a8f4d8cd95e164917035b64b867a45dd"]}}; /* ]]> */
#   </script>
#   <script>
#    /* <![CDATA[ */ ringDataLayer = {"context":{"variant":{"accelerator":"Ym90LXRyYWZmaWMuY2xvdWQub25ldDo6bWFpbg=="}},"content":{"object":{"type":"home"}}}; /* ]]> */
#   </script>
#   <script>
#    /* <![CDATA[ */ accConf = {"events":{"endpointPaths":["/a8f4d8cd95e164917035b64b867a45dd"]}}; /* ]]> */
#   </script>
#   <meta content="block-all-mixed-content" httpequiv="Content-Security-Policy"/>
#   <meta content="strict-origin-when-cross-origin" name="referrer"/>
#   <link href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/pwa-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link color="#ffd200" href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="https://ocdn.eu/onetmobilemainpage/browser/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta name="next-font-preconnect"/>
#   <script defer="" nomodule="" src="https://static.onet.pl/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/3438-ddf13b560c8c9fa7.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/9331-5c4fdbb5c18787f7.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/126-4096089857defb85.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/3253-9e9a3cc9e93073cc.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/9074-77c70b425ec0e32c.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/2276-c0d4cf0412f3128b.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/5609-5fcb5e0732a1fad6.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/1805-6f8aa23ef21fa2a9.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/2632-ca3dbeacb87a7b3e.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/9473.90697b01836dfeb9.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/9554.fdd24a2b65a432cc.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/4130.eba8cb4a078a0161.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/6906.4084f97dc66381c2.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/3602.b29268ef7653c729.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/4959.2e48d5e1d1c1136f.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/7214.8ac1f6b71910a1b3.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/9955.2cf3d8b244fed39f.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/2892.b8f94615c440f019.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/6740.dc38df2792025317.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/6070.d4a149b27c0d4d9f.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/1788.65dda4ca990cb15e.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/4678.3ce639edeecb9209.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/2701.875532d75c223b15.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/296.c21b26199e7964bb.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/3165.eb69534c60fd3796.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/6039.742920715459febc.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/7938.6391a305b87be459.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/9773.3a9f4db99c48b4da.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/webpack-3b4524ca268536f2.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/framework-ebb493f39c522d88.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/main-123a83373baf61ce.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/pages/_app-3288f323024ba0f8.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/chunks/pages/index-f45b5c0a9b0d5b17.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/Sj_j8Tvjio7MBs9_FkvBj/_buildManifest.js">
#   </script>
#   <script defer="" src="https://static.onet.pl/_next/static/Sj_j8Tvjio7MBs9_FkvBj/_ssgManifest.js">
#   </script>
#   <style>
#    *{padding:0;list-style-type:none;text-decoration:none;box-sizing:border-box}*,body{margin:0}body{font-family:Fira Sans,Arial,Helvetica,sans-serif;font-size:16px;min-height:100%;position:relative;-webkit-tap-highlight-color:rgba(255,210,0,.5);background-color:#eaeaea;overflow-y:scroll}html{height:100%;width:100%;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;text-size-adjust:100%}html.device-bot{min-width:1274px}@media screen and (max-width:1366px){html.device-bot{min-width:1248px}}iframe{border:none}[class*=" icon-"]:after,[class*=" icon-"]:before,[class^=icon-]:after,[class^=icon-]:before{font-family:onetsg;speak:none;font-style:normal;font-weight:400;font-feature-settings:normal;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon-loupe:before{content:""}.iconStroke.icon-video:before{content:""}.iconFilled.icon-video:before{content:""}iframe,img{aspect-ratio:attr(width)/attr(height)}#onet-ad-flat-belkagorna{overflow:hidden;width:100%}body.device-bot{background-color:#fff;padding-top:100px}body.device-bot #onet-ad-flat-belkagorna{display:none}#adslot-top{width:1274px;margin:0 auto}#__phx_modal:not(:empty):before{content:" ";width:100%;height:100vw;display:block;position:absolute;transform:rotateX(180deg);transform-origin:0 0;transition:background 0s linear .5s;pointer-events:none}.Image_image__EUPoV{position:relative;display:block}.PremiumLabel_container__9N2_n{background-image:url(https://ocdn.eu/omp3/static_files/images/labels/premium_label_big_photo.svg);background-repeat:no-repeat;position:absolute}.PremiumLabel_StandardPremiumCardLabel__s2zQd{width:66px;height:17px;top:10px;right:10px}.PremiumLabel_BigCardPremiumLabel__LL8WC{width:94px;height:24px;top:10px;right:10px}.BigCard_BigCardDefault__HDt3d{position:relative;width:620px}@media screen and (max-width:1366px){.BigCard_BigCardDefault__HDt3d{width:612px;overflow:hidden}}.BigCard_BigCardTextWrapper__ytJoa{position:absolute;bottom:20px}.BigCard_BigCardTitle__QszMz{display:block;font-weight:700;font-size:1.75em;letter-spacing:-.4px;line-height:1.10714285;position:relative}.BigCard_BigCardTitleStd__Zf73g{max-width:560px;min-width:550px}.BigCard_BigCardTitleMozaic__v_Ltf{max-width:450px;min-width:450px}.BigCard_BigCardLabel__HGVko{position:absolute;top:10px;right:10px}.BigCard_BigCardPictogram__S75mS{position:absolute;bottom:10px;right:10px;color:#fff}.BigCard_default__k16jA{border-left:6px solid #ffd200;text-shadow:0 1.1px 2px #333;left:0;padding-left:19px}.BigCard_onetonly__82jz6{background-color:#ffd200;left:25px;padding:8px 14px}.SmallCard_smallCard__UN_eb{min-height:70px;padding-top:10px;position:relative}.SmallCard_smallCard__UN_eb:hover{background:linear-gradient(90deg,#fff 0,#efefef 23%,#fff)}.SmallCard_bottomLine__1aYLv{border-bottom:1px dotted #dcdcdc;min-width:100%}.SmallCard_smallCardLink__FW9JN{display:flex;position:relative}.SmallCard_smallCardTitle__x7IRD{font-size:.875em;height:55px;overflow:hidden;min-height:70px;font-weight:500;line-height:1.25}.SmallCard_smallCardImage__15Pr7{margin:0 10px 10px 0;height:59px}.SmallCard_smallCardCardPictogram__4k5_P{position:absolute;left:70px;bottom:15px;color:#fff}.CollapsedItem_itemLinkSimple__i5zoz{font-size:.875em;font-weight:400;line-height:1.29;padding:16px 25px;text-transform:uppercase}.CollapsedItem_itemLinkWithImage__nKY1h{height:79px;padding:12px;position:relative}.CollapsedItem_itemLinkSimple__i5zoz,.CollapsedItem_itemLinkWithImage__nKY1h{color:#1e1e1e;display:block;text-decoration:none}.CollapsedItem_itemLinkSimple__i5zoz:hover,.CollapsedItem_itemLinkWithImage__nKY1h:hover{background:#e9e9e9}.CollapsedItem_itemImage__fuQNL{float:left;margin-right:12px}.CollapsedItem_itemTitle__lBo_9{font-weight:500;font-size:1em;line-height:1.29}.CollapsedItem_itemMore__YmNFZ{bottom:13px;display:block;font-size:.75em;font-weight:300;left:120px;position:absolute}.CollapsedItem_itemBorder__woYv_{border-top:1px dotted #ccc}.CollapsedItem_i ...
#   </style>
#   <link data-n-g="" href="https://static.onet.pl/_next/static/css/f2cf545551edd581.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <noscript>
#    <link href="https://static.onet.pl/_next/static/css/f2cf545551edd581.css" rel="stylesheet"/>
#   </noscript>
#   <link href="https://static.onet.pl/_next/static/css/e6bdeecbd4025c0f.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <noscript>
#    <link href="https://static.onet.pl/_next/static/css/e6bdeecbd4025c0f.css" rel="stylesheet"/>
#   </noscript>
#   <link href="https://static.onet.pl/_next/static/css/8a3bcccf1dd7101e.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <noscript>
#    <link href="https://static.onet.pl/_next/static/css/8a3bcccf1dd7101e.css" rel="stylesheet"/>
#   </noscript>
#   <link href="https://static.onet.pl/_next/static/css/f2ce12785d415e6f.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <noscript>
#    <link href="https://static.onet.pl/_next/static/css/f2ce12785d415e6f.css" rel="stylesheet"/>
#   </noscript>
#   <link href="https://static.onet.pl/_next/static/css/df85d247834a96f8.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#   <noscript>
#    <link href="https://static.onet.pl/_next/static/css/df85d247834a96f8.css" rel="stylesheet"/>
#   </noscript>
#   <noscript data-n-css="">
#   </noscript>
#   <script data-original="https://sgqcvfjvr.onet.pl/YnVpbGQvezlza2x0MjA1fWRsQXBpL2RsLmxpYntOTWFzXzIwNX0ubWluLmpz" id="adsinit">
#    /* <![CDATA[ */
# !function(e){var t={};function n(r){if(t[r])return t[r].exports;var i=t[r]={i:r,l:!1,exports:{}};return e[r].call(i.exports,i,i.exports,n),i.l=!0,i.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&t&&(e=n(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var r=Object.create(null);if(n.r(r),Object.defineProperty(r,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var i in e)n.d(r,i,function(t){return e[t]}.bind(null,i));return r},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="",n(n.s=23)}([function(e,t){e.exports={check:function(){try{return window.self!==window.top}catch(e){return!0}}}},function(e,t){e.exports=function(e,t){var n=(t=t||document).createElement("style");return n.type="text/css",n.styleSheet?n.styleSheet.cssText=e:n.innerHTML=e,t.getElementsByTagName("head")[0].appendChild(n),n}},function(e,t){var n={},r=["onet_ad_network"],i=function(e,t){return t?e:decodeURIComponent(e||"")||null};e.exports={get:function(e,t){if(t=t||!1,function(e){return-1!==r.indexOf(e)&&void 0!==n[e]}(e))return i(n[e],t);for(var o=e+"=",a=document.cookie.split(";"),c=0;c<a.length;c++){for(var s=a[c];" "===s.charAt(0);)s=s.substring(1);if(0===s.indexOf(o)){var d=s.substring(o.length,s.length);return d=i(d,t),n[e]=d,d}}return n[e]=null,null}}},function(e,t){var n="https://sgqcvfjvr.onet.pl/",r=/^(?:\w+:)?\/\//;n="https://"+(r.test(n)?n.replace(r,""):"lib.onet.pl/s.csr/"),e.exports={proto:"https://",base:n}},function(e,t,n){var r=n(5),i=n(6),o=n(1),a=n(18),c="whitelistPremium",s="Reklamy nie są takie złe... To dzięki nim masz darmowy dostęp do naszych najlepszych treści. Prosimy, odblokuj wyświetlanie reklam w naszym serwisie.".split(/\s+/);s.index=0;var d=function(e,t){if(!t.document.referrer||t.document.referrer!=t.location.href&&/^\w+:\/\//i.test(t.document.referrer)){var n=e.baseUrl.replace(/^((?:\w+:)?\/\/[^\/?&#]+).*/,"$1"),r=t.document.createElement("iframe");v(t,"message",(function(r){(r.origin||r.originalEvent.origin)==n&&"noadp"==r.data&&(g(e,"Adblock_whitelist","refresh"),t.location=t.location.href)})),r.width=0,r.height=0,r.frameborder=0,t.document.body.appendChild(r),r.src=[e.baseUrl,"MDI2NjA0MS9idWlsZC9kbEFwaS9kbC53aGwubWlu",".","html","?","v=",parseInt(Date.now()/1e7)].join("")}else h()},l=function(e){o("."+c+",."+c+" *{text-decoration:none !important}");!function t(){for(var n=(r=document.querySelectorAll("."+c+":not([data-"+c+"])")).length-1;n>=0;--n)f(e,r[n]).setAttribute("data-"+c,1);n=0;for(var r=document.querySelectorAll(".whitelistContent");n<r.length;++n)u(e,r[n]);setTimeout(t,5e3)}()},u=function(e,t){t.parentNode&&t.parentNode.removeChild(t)},f=function e(t,n){if(n.hasAttribute("data-"+c))return n;var r=n.nodeName.toLowerCase(),o=n.getAttribute("data-run-module");if(["img","canvas","svg","math","iframe","video","object","embed","audio"].indexOf(r)>=0||"embeddedapp/main.onettvplayer"==o||"local/main.player"==o||"pulsembed/pulsembed.init"==o&&n.innerHTML.indexOf("//onet.tv/")>=0||"embeddedapp/main.app"==o&&(""+n.getAttribute("data-params")).indexOf("//onet.tv/")>=0||/^mvp:/.test(n.id)){for(var a=t.document.createElement("div"),d=i(n),l=0;l<d.length;++l){var u=d[l];a.style[u]=d[u]}if(a.style.display="inline-block",["img","canvas","svg","math"].indexOf(r)>=0)a.style.background="#e2e3e7 url(//mastt.ocdn.eu/MDA_/74f6b5ce7ae8d0bdfce96970fc71bd47.jpg) no-repeat center",a.style.backgroundSize="contain";else{a.style.background="#e2e3e7 url(//mastt.ocdn.eu/MDA_/42f492f4c603c2817813a90dc951904c.jpg) no-repeat center";var f=n.getAttribute("data-height-hint");f&&(a.style.paddingBottom=f)}return n.parentNode.replaceChild(a,n ...
# /* ]]> */
#   </script>
#  </head>
#  <body class="device-bot">
#   <div id="__next">
#    <div class="onet-ad" data-autoslot="0" data-section="" id="onet-ad-flat-belkagorna">
#    </div>
#    <header class="Header_header__WNsOp pageHeader Header_headerExpanded__KVQVS" data-section="header">
#     <div class="Header_wrapper__vR_2W">
#      <div class="Header_logoWrapper__lO7er">
#       <div class="Header_logoContainer__msbBu">
#        <h1 class="Logo_wrapper__7xSbc Logo_expanded__OpOyY onetLogo">
#         <a class="Logo_logoLink__LpkW5" href="/">
#          <svg height="100%" viewBox="0 0 77 24" width="100%">
#           <path class="logo-cls-1" d="M50.315,89.332a6.345,6.345,0,1,1,6.4-6.344,6.291,6.291,0,0,1-6.4,6.344m0-9.6a3.258,3.258,0,1,0,3.225,3.258,3.124,3.124,0,0,0-3.225-3.258M66.217,89V82.009a2.187,2.187,0,0,0-2.337-2.422,2.892,2.892,0,0,0-2.6,1.663V89H58.105V77h2.777V78.23a5.009,5.009,0,0,1,3.934-1.586,4.468,4.468,0,0,1,3.25,1.293,5.155,5.155,0,0,1,1.325,3.691V89H66.217Zm23.611,0.21a4.277,4.277,0,0,1-3.139-1.03,4.077,4.077,0,0,1-1-3.022V79.994H83.7V77h1.984V74.2l3.174-.751V77H92v3H88.86v5.2c0,0.47.272,1.069,1.566,1.069,0.568,0,1.542-.119,1.542-0.119v2.816a10.862,10.862,0,0,1-2.14.247M77.4,89.332c-3.895,0-6.615-2.609-6.615-6.345a6.244,6.244,0,1,1,12.486,0,7.048,7.048,0,0,1-.121,1.274l-0.006.031H74.112a3.115,3.115,0,0,0,3.333,2.168,3.351,3.351,0,0,0,2.527-1.023l2.6,1.441a6.119,6.119,0,0,1-5.18,2.453m2.687-7.506a2.864,2.864,0,0,0-2.927-2.334,2.96,2.96,0,0,0-3.095,2.334h6.022Z" style="fill: #1e1e1e;" transform="translate(-15 -71)">
#           </path>
#           <path class="logo-cls-2" d="M39.117,83A12.059,12.059,0,1,1,27.058,71,12.029,12.029,0,0,1,39.117,83" style="fill: #ffd200;" transform="translate(-15 -71)">
#           </path>
#          </svg>
#         </a>
#        </h1>
#        <div class="onet-ad" data-autoslot="0" data-section="ad-flat-ikona" id="onet-ad-flat-ikona">
#        </div>
#       </div>
#      </div>
#      <div class="Header_menu__xYibt">
#       <form action="https://szukaj.onet.pl/wyniki.html" class="Search_wrapper__FwACT">
#        <input autocomplete="off" class="Search_field__e_FQj" name="qt" placeholder=" " type="search"/>
#        <span class="icon-loupe Search_loupe__LnwXk Search_placeholder__Z5Pxt">
#        </span>
#        <span class="Search_placeholderText__h_aT2 Search_placeholder__Z5Pxt">
#         Szukaj
#        </span>
#        <span class="Search_google__HgD2C Search_placeholder__Z5Pxt">
#         <svg class="google_svg__mainIconPack" id="google_svg__poweredByGoogle" role="img" viewBox="0 0 259.33 40.91" xmlns="http://www.w3.org/2000/svg">
#          <defs>
#           <style>
#            .google_svg__google1,.google_svg__google3{fill:#ea4335;fill-opacity:.8}.google_svg__google3{fill:#4285f4}.google_svg__google5{fill:#c8c8c8;opacity:0}
#           </style>
#          </defs>
#          <path class="google_svg__google1" d="M190.9 49.85a10.26 10.26 0 1 1-10.26-10.22 10.1 10.1 0 0 1 10.26 10.22Zm-4.49 0a5.78 5.78 0 1 0-11.53 0 5.78 5.78 0 1 0 11.53 0Z" transform="translate(-2.67 -28.32)">
#          </path>
#          <path d="M213 49.85a10.26 10.26 0 1 1-10.26-10.22A10.1 10.1 0 0 1 213 49.85Zm-4.49 0a5.78 5.78 0 1 0-11.53 0 5.78 5.78 0 1 0 11.56 0Z" style="fill: #fbbc05; fill-opacity: 0.8;" transform="translate(-2.67 -28.32)">
#          </path>
#          <path class="google_svg__google3" d="M234.23 40.24V58.6c0 7.55-4.45 10.63-9.72 10.63a9.74 9.74 0 0 1-9.06-6l3.91-1.63a5.65 5.65 0 0 0 5.15 3.63c3.37 0 5.46-2.08 5.46-6v-1.49h-.16a7 7 0 0 1-5.38 2.32 10.23 10.23 0 0 1 0-20.44 7.08 7.08 0 0 1 5.38 2.29h.19v-1.66h4.26Zm-3.95 9.64c0-3.6-2.4-6.23-5.46-6.23a5.91 5.91 0 0 0-5.69 6.23 5.87 5.87 0 0 0 5.7 6.12c3.05 0 5.45-2.55 5.45-6.12Z" transform="translate(-2.67 -28.32)">
#          </path>
#          <path d="M241.26 29.48v30h-4.38v-30h4.38Z" style="fill: #34a853; fill-opacity: 0.8;" transform="translate(-2.67 -28.32)">
#          </path>
#          <path class="google_svg__google1" d="m258.32 53.21 3.48 2.32a10.18 10.18 0 0 1-8.52 4.53 10 10 0 0 1-10.15-10.22c0-6.08 4.37-10.22 9.64-10.22s7.9 4.22 8.75 6.5l.48 1.16-13.67 5.66a5.2 5.2 0 0 0 5 3.1 5.83 5.83 0 0 0 5-2.83Zm-10.72-3.68 9.14-3.79a4 4 0 0 0-3.79-2.17 5.61 5.61 0 0 0-5.35 5.96Z" transform="translate(-2.67 -28.32)">
#          </path>
#          <path class="google_svg__google3" d="M153.81 47.19v-4.34h14.62a14.37 14.37 0 0 1 .22 2.62c0 3.25-.89 7.28-3.76 10.15a14.52 14.52 0 0 1-11.07 4.45 16.1 16.1 0 0 1-16.11-15.87 16.1 16.1 0 0 1 16.11-15.87 15.13 15.13 0 0 1 10.88 4.37l-3.06 3.06a11.06 11.06 0 0 0-7.82-3.1 11.54 11.54 0 0 0 0 23.07 10.62 10.62 0 0 0 8-3.18 9 9 0 0 0 2.35-5.37h-10.36Z" transform="translate(-2.67 -28.32)">
#          </path>
#         </svg>
#        </span>
#        <button class="Search_button__oKxuf" type="submit">
#         Szukaj
#        </button>
#       </form>
#       <div class="ServiceMenu_wrapper__eXXV_" data-element-type="serviceMenu">
#        <a class="MenuIcon_menuItem__T1hht ServiceMenu_iconItem__tuHpy" data-staticr="skip" href="https://m.sympatia.onet.pl/?utm_source=m.onet.pl&amp;utm_medium=banner&amp;utm_campaign=ikona">
#         <svg class="MenuIcon_icon__ac4PH" role="img" viewBox="0 22 38 34" xmlns="http://www.w3.org/2000/svg">
#          <path d="M35.1 25c-1.9-2-4.4-3-7.2-3s-5.4 1.1-7.4 3.2L19 26.7l-1.5-1.5c-2-2.1-4.6-3.2-7.4-3.2-2.7 0-5.3 1.1-7.2 3-3.9 4.1-3.9 10.8.2 15l15.2 15.7c.2.2.4.3.7.3s.5-.1.7-.3L34.9 40c4.1-4.2 4.1-10.9.2-15zm-1.6 13.6L19 53.6l-14.5-15c-3.3-3.4-3.4-8.9-.1-12.2 1.5-1.6 3.5-2.4 5.7-2.4 2.3 0 4.4.9 6 2.6l2.2 2.3c.4.4 1.1.4 1.4 0l2.2-2.3c1.6-1.7 3.7-2.6 6-2.6 2.2 0 4.2.9 5.7 2.4 3.3 3.3 3.2 8.8-.1 12.2z">
#          </path>
#         </svg>
#         <span class="MenuIcon_labelText__0n1xb MenuIcon_showLabelText__MurLA">
#          Sympatia
#         </span>
#        </a>
#        <a class="MenuIcon_menuItem__T1hht ServiceMenu_iconItem__tuHpy" data-staticr="skip" href="http://gameplanet.onet.pl/?utm_source=m.onet.pl&amp;utm_medium=banner&amp;utm_campaign=ikona">
#         <svg class="MenuIcon_icon__ac4PH" role="img" viewBox="-0.06 15.8 29.03 40.2" xmlns="http://www.w3.org/2000/svg">
#          <path d="m1.8 27.1 2 1.1c.2.1.3.1.5.1.4 0 .7-.2.9-.5.3-.5.1-1.1-.4-1.4l-2-1.1c-.5-.3-1.1-.1-1.4.4s-.1 1.1.4 1.4zm27.1 27.6c-.2-.5-1.6-4.7-3.7-6-.2-.1-.3-.1-.5-.1h-19c-.2 0-.3 0-.5.1-2.3 1.2-3.6 5.5-3.7 6-.1.3 0 .6.2.9.1.3.4.4.7.4H28c.3 0 .6-.2.8-.4.2-.3.2-.6.1-.9zm-25-.7c.5-1.3 1.3-2.8 2.1-3.4h18.4c.8.6 1.6 2.1 2.1 3.4H3.9zm1.3-13.2c2.1 1.3 2.1 4 2 4.1V46H24v-1c.3-7-5.1-11.4-7.5-13 1.4-.1 4.6.5 7.7 1.5h.2c1.5.2 2.3-.3 2.7-.8 1.2-1.4.6-3.8.6-4.1v-.2l-.1-.1c-1.2-1.8-6.3-5.5-7.5-6.4l-.8-1.7-3.1-.5v-3.9L15 16c-3.4.5-5 2.6-5.6 3.7-.9.2-2.7.7-4.1 2.4l-.4-.3c-.4-.3-1.1-.3-1.4.2-.3.4-.3 1.1.2 1.4l1.8 1.4c.2.1.4.2.6.2.3 0 .6-.1.8-.4.3-.4.3-.9-.1-1.3 1.4-1.7 3.2-1.8 3.3-1.8h.7l.2-.5s.7-1.9 3.1-2.7v3.2l3.8.6.6 1.2.2.1c1.6 1.2 5.9 4.5 7.1 6 .1.6.2 1.7-.2 2.1-.2.2-.5.2-.8.1-2-.7-8.1-2.5-10.1-1-.5.4-.8 1-.7 1.7v.6l.5.3c.1 0 7.3 3.9 7.6 10.9H9.2c-.2-1.3-.8-3.5-2.9-4.8-2.7-1.7-3.2-3.8-2.9-7.4.4 0 .8-.3 1-.7.2-.5-.1-1.1-.7-1.3l-2.4-.7c-.5-.2-1.1.1-1.3.7-.2.5.1 1.1.7 1.3l.7.2c-.5 4.1.1 7.1 3.8 9.4z">
#          </path>
#         </svg>
#         <span class="MenuIcon_labelText__0n1xb MenuIcon_showLabelText__MurLA">
#          Gry
#         </span>
#        </a>
#        <a class="MenuIcon_menuItem__T1hht ServiceMenu_iconItem__tuHpy" data-staticr="skip" href="https://vod.pl/?utm_source=m.onet.pl&amp;utm_medium=banner&amp;utm_campaign=ikona">
#         <svg class="MenuIcon_icon__ac4PH" role="img" viewBox="0 17 38 38" xmlns="http://www.w3.org/2000/svg">
#          <path d="M17.1 28c-.3-.2-.7-.3-1.1-.1-.3.2-.5.5-.5 1v14.4c0 .4.2.7.6 1 .1.1.3.1.4.1.2 0 .5-.1.6-.2l9.2-7.5c.2-.2.4-.5.4-.8s-.2-.6-.4-.8L17.1 28zm.4 13V31l6.4 4.8-6.4 5.2zM19 17C8.6 17 0 25.6 0 36s8.6 19 19 19 19-8.5 19-19-8.6-19-19-19zm0 35.9C9.7 52.9 2.1 45.3 2.1 36S9.7 19.1 19 19.1 35.9 26.7 35.9 36 28.3 52.9 19 52.9z">
#          </path>
#         </svg>
#         <span class="MenuIcon_labelText__0n1xb MenuIcon_showLabelText__MurLA">
#          VOD
#         </span>
#        </a>
#        <a class="MenuIcon_menuItem__T1hht ServiceMenu_iconItem__tuHpy" data-staticr="skip" href="https://gratka.pl/?utm_source=rasp&amp;utm_medium=onet-header-icon&amp;utm_campaign=onet-icon">
#         <svg class="MenuIcon_icon__ac4PH" role="img" viewBox="0.23 12.11 71.51 47.93" xmlns="http://www.w3.org/2000/svg">
#          <path d="M.23 12.11v47.93h54.34l.01-14.13 2.25-2.11 4.34 3.08 4.23-3.51 6.34 4.04v-35.3H.23zm68.4 29.61-3.46-2.2-4.14 3.43-4.47-3.17-5.1 4.78v1.37h-.01v10.99H37.71V44.19h-3.12v12.72H20.53V44.19h-3.12v12.72H3.35V15.23h65.27v26.49z">
#          </path>
#          <path d="M8.66 20.85h54.86v3.12H8.66zM8.66 28h54.86v3.12H8.66zM8.66 35.15h42.58v3.12H8.66zM8.52 44.29h3.12v8.13H8.52zM25.9 44.29h3.12v8.13H25.9zM42.96 44.29h3.12v8.13h-3.12z">
#          </path>
#         </svg>
#         <span class="MenuIcon_labelText__0n1xb MenuIcon_showLabelText__MurLA">
#          Ogłoszenia
#         </span>
#        </a>
#        <a class="MenuIcon_menuItem__T1hht ServiceMenu_iconItem__tuHpy" data-staticr="skip" href="https://premium.onet.pl/?src=headerOnetHP">
#         <svg class="MenuIcon_icon__ac4PH" id="paid" style="enable-background:new 0 0 105 36;height:35px;" version="1.1" viewBox="0 0 105 36" x="0px" xmlns="http://www.w3.org/2000/svg" xmlspace="preserve" y="0px">
#          <radialGradient cx="-90.3669" cy="-3.8678" gradientTransform="matrix(104.9426 0 0 -110.6991 9535.8721 -428.1627)" gradientUnits="userSpaceOnUse" id="paid_gradient_1666864715428" r="3.1739">
#           <stop offset="0" style="stop-color:#0578BE">
#           </stop>
#           <stop offset="1.900000e-02" style="stop-color:#0773BA">
#           </stop>
#           <stop offset="0.13" style="stop-color:#1753A2">
#           </stop>
#           <stop offset="0.25" style="stop-color:#27348B">
#           </stop>
#           <stop offset="0.48" style="stop-color:#1F195B">
#           </stop>
#           <stop offset="0.65" style="stop-color:#19083C">
#           </stop>
#           <stop offset="1" style="stop-color:#19083C">
#           </stop>
#          </radialGradient>
#          <path d="M17.8,0h69.5 C97.1,0,105,7.9,105,17.7c0,0.2,0,0.4,0,0.5c0,9.8-7.9,17.7-17.7,17.7l-69.5,0C8,36,0,28,0.1,18.2c0-0.2,0-0.4,0-0.5 C0.1,7.9,8,0,17.8,0z" id="gradient" style="fill:url(#paid_gradient_1666864715428);">
#          </path>
#          <g id="O_premium" transform="translate(15 10.669)">
#           <g id="Group_1446" transform="translate(17.736 0.046)">
#            <path d="M55.8,4.1c-0.5-0.5-1.2-0.8-2-0.8c-0.9,0-1.8,0.3-2.4,1l-0.2-0.2c-0.2-0.2-0.5-0.4-0.8-0.6 c-0.4-0.1-0.7-0.2-1.1-0.2c-0.9,0-1.8,0.3-2.4,1V3.5h-1.7v7.2h1.9V6.1c0.3-0.6,0.9-1,1.6-1c0.4,0,0.8,0.1,1,0.4s0.4,0.7,0.4,1.1 v4.2H52V6.3c0-0.2,0-0.5-0.1-0.7C52.2,5.2,52.7,5,53.2,5c0.7,0,1.4,0.5,1.4,1.2c0,0.1,0,0.2,0,0.2v4.2h1.9V6.3 C56.7,5.5,56.4,4.7,55.8,4.1z" id="Path_859" style="fill:#ffffff">
#            </path>
#            <path d="M39.3,3.5v4.2c-0.1,0.7,0.4,1.4,1.2,1.5c0.1,0,0.2,0,0.2,0c0.7,0,1.3-0.4,1.6-1V3.5h1.9v7.2 h-1.7V10c-0.6,0.7-1.5,1-2.4,1c-0.7,0-1.4-0.3-2-0.8c-0.5-0.6-0.8-1.4-0.8-2.2V3.5H39.3z" id="Path_860" style="fill:#ffffff">
#            </path>
#            <path d="M32.1,4.1c-0.5-0.5-1.2-0.8-2-0.8c-0.9,0-1.8,0.3-2.4,1l-0.2-0.2c-0.2-0.2-0.5-0.4-0.8-0.6 c-0.4-0.1-0.7-0.2-1.1-0.2c-0.9,0-1.8,0.3-2.4,1V3.5h-1.7v7.2h1.9V6.1c0.3-0.6,0.9-1,1.6-1c0.4,0,0.8,0.1,1,0.4s0.4,0.7,0.4,1.1 v4.2h1.9V6.3c0-0.2,0-0.5-0.1-0.7C28.5,5.2,29,5,29.5,5C30.3,5,31,5.6,31,6.3c0,0.1,0,0.2,0,0.2v4.2h1.9V6.3 C33,5.5,32.7,4.7,32.1,4.1z" id="Path_861" style="fill:#ffffff">
#            </path>
#            <path d="M16.9,11c-2.1,0.1-3.9-1.6-4-3.7s1.6-3.9,3.7-4c0.1,0,0.1,0,0.2,0c2,0,3.7,1.6,3.7,3.7 c0,0.1,0,0.1,0,0.2c0,0.3,0,0.5-0.1,0.8l0,0H15c0.3,0.9,1.1,1.4,2,1.3c0.6,0,1.1-0.2,1.5-0.6L20,9.5C19.3,10.5,18.1,11,16.9,11z M18.5,6.5C18.4,5.6,17.6,5,16.8,5c-0.9-0.1-1.7,0.5-1.9,1.4L18.5,6.5L18.5,6.5z" id="Path_862" style="fill:#ffffff">
#            </path>
#            <path d="M3.9,3.3C3,3.3,2.2,3.7,1.7,4.4V3.5H0v9.6h1.9V10c0.5,0.6,1.2,0.9,2,0.9c0.9,0,1.8-0.4,2.5-1.1 c1.4-1.6,1.4-3.9,0-5.5C5.7,3.7,4.8,3.3,3.9,3.3z M5.5,7.1c0.1,1.1-0.7,2-1.7,2.1c-0.1,0-0.1,0-0.2,0c-0.7,0-1.3-0.4-1.7-1V6.1 c0.4-0.6,1-1,1.7-1c1.1,0,1.9,0.8,2,1.8C5.5,7,5.5,7.1,5.5,7.1L5.5,7.1z" id="Path_863" style="fill:#ffffff">
#            </path>
#            <path d="M13.3,3.5c-0.4-0.1-0.8-0.2-1.2-0.2c-0.8,0-1.5,0.5-1.9,1.2v-1H8.3v7.3h1.9V6 c0.3-0.6,0.9-0.9,1.6-1c0.1,0,0.3,0,0.4,0l0,0l0,0C12.5,4.5,12.8,4,13.3,3.5L13.3,3.5L13.3,3.5z" id="Path_864" style="fill:#ffffff">
#            </path>
#            <path d="M35.1,0c0.7,0,1.2,0.5,1.2,1.2s-0.5,1.2-1.2,1.2s-1.2-0.5-1.2-1.2S34.5,0,35.1,0L35.1,0z M34.2,3.5H36v7.2h-1.8V3.5z" id="Path_865" style="fill:#ffffff">
#            </path>
#           </g>
#           <circle cx="7.4" cy="7.4" id="Ellipse_2" r="7.4" style="fill:#ffd200">
#           </circle>
#          </g>
#         </svg>
#         <span class="MenuIcon_prefix__7FwAT">
#          sprawdź!
#         </span>
#         <span class="MenuIcon_labelText__0n1xb MenuIcon_showLabelText__MurLA">
#         </span>
#        </a>
#        <a class="MenuIcon_menuItem__T1hht MenuIcon_highlighted__X7zNd" data-staticr="skip" href="https://poczta.onet.pl/">
#         <svg class="MenuIcon_icon__ac4PH" role="img" viewBox="28 22.5 36 27" xmlns="http://www.w3.org/2000/svg">
#          <path d="M28 22.5v27h36v-27H28zm33.69 2.382v1.89l-15.835 7.879-15.545-7.875v-1.894h31.38zM30.31 47.118v-17.54l15.534 7.87 15.845-7.884v17.554H30.31z">
#          </path>
#         </svg>
#         <span class="MenuIcon_labelText__0n1xb MenuIcon_showLabelText__MurLA">
#          E-mail
#         </span>
#        </a>
#       </div>
#       <div class="Header_profileIcon__2NwD8 Avatar_notLogged__QrEz5" data-onboarding="header-profile-icon">
#        <svg role="img" viewBox="0 0 60 60">
#         <defs>
#          <style>
#           .profile_svg__profile_ico_b{fill:none;stroke:#1e1e1e;stroke-linecap:round;stroke-linejoin:round;stroke-width:2px}
#          </style>
#         </defs>
#         <g transform="translate(14.5 12.816)">
#          <circle cx="30" cy="30" fill="none" r="30" transform="translate(-14.5 -12.816)">
#          </circle>
#          <path class="profile_svg__profile_ico_b" d="M22.789 24.806a6.925 6.925 0 0 1-.981-2.985m-10.683-.318a9.52 9.52 0 0 1-.915 3.3M16.508 23.636h.125c1.707-.007 3.4-.347 4.077-1.024a20.1 20.1 0 0 0 4.595-14.155c-.536-5.81-4.244-8.452-8.806-8.452s-8.25 2.632-8.788 8.452a20.094 20.094 0 0 0 4.6 14.155c.675.677 2.369 1.016 4.076 1.024h.125M33 31.184c-.95-3.7-10.21-6.378-10.21-6.378m-12.58 0S.95 27.487 0 31.184">
#          </path>
#         </g>
#        </svg>
#       </div>
#       <div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="PageGroup_page__lBI6i" data-name="Page page_1" data-pagetype="page">
#     <div class="PageGroup_wide__9lQ9u" data-name="wide" data-pagetype="container">
#      <nav class="Menu_navContainer__e7Br0" data-section="sitenavigation">
#       <div class="Menu_navWrapper__lQTfH">
#        <div class="Menu_navMenuListItem__IRxhU">
#         <a class="Menu_navMenuLink__Qde0X" data-staticr="skip" href="https://wiadomosci.onet.pl/">
#          Wiadomości
#         </a>
#        </div>
#        <div class="Menu_navMenuListItem__IRxhU">
#         <a class="Menu_navMenuLink__Qde0X" data-staticr="skip" href="https://sport.onet.pl/">
#          Sport
#         </a>
#        </div>
#        <div class="Menu_navMenuListItem__IRxhU Menu_premium__V1R9I">
#         <a class="Menu_navMenuLink__Qde0X" href="https://www.onet.pl/premium">
#          Premium
#          <span class="Menu_moreArrow__VYHyj">
#          </span>
#         </a>
#         <div class="Menu_subMenu__YLGLv CollapsedItems_collapsedMenu__l_XFH CollapsedItems_hidden__M8QZm" style="transform: translate(0px, 0);">
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://premium.onet.pl/?src=siteNavigationOnet">
#            Kup Onet Premium
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/forbes?src=siteNavigationOnet">
#            Forbes
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/autoswiat?src=siteNavigationOnet">
#            Auto Świat
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/bild?src=siteNavigationOnet">
#            Bild
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/noizz?src=siteNavigationOnet">
#            Noizz
#           </a>
#          </div>
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium?src=siteNavigationOnet">
#            Wszystkie
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/przegladsportowy?src=siteNavigationOnet">
#            Przegląd Sportowy
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/vogue?src=siteNavigationOnet">
#            Vogue Polska
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/komputerswiat?src=siteNavigationOnet">
#            Komputer Świat
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/ofeminin?src=siteNavigationOnet">
#            Ofeminin
#           </a>
#          </div>
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/onet?src=siteNavigationOnet">
#            Onet
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/politico?src=siteNavigationOnet">
#            Politico
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/kontynenty?src=siteNavigationOnet">
#            Kontynenty
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/nationalgeographic?src=siteNavigationOnet">
#            National Geographic
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/archinea?src=siteNavigationOnet">
#            Archinea
#           </a>
#          </div>
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/newsweek?src=siteNavigationOnet">
#            Newsweek
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/forbeswomen?src=siteNavigationOnet">
#            Forbes Women
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/diewelt?src=siteNavigationOnet">
#            Die Welt
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/newsweeklearningenglish?src=siteNavigationOnet">
#            Newsweek Learning English
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" href="https://www.onet.pl/premium/liberte?src=siteNavigationOnet">
#            Liberte
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="Menu_navMenuListItem__IRxhU">
#         <a class="Menu_navMenuLink__Qde0X" data-staticr="skip" href="https://businessinsider.com.pl/">
#          Biznes
#         </a>
#        </div>
#        <div class="Menu_navMenuListItem__IRxhU">
#         <a class="Menu_navMenuLink__Qde0X" data-staticr="skip" href="#">
#          Regionalne
#          <span class="Menu_moreArrow__VYHyj">
#          </span>
#         </a>
#         <div class="Menu_subMenu__YLGLv CollapsedItems_collapsedMenu__l_XFH CollapsedItems_hidden__M8QZm" style="transform: translate(0px, 0);">
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://bialystok.onet.pl/">
#            Białystok
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://kujawsko-pomorskie.onet.pl/">
#            Kujawsko-Pomorskie
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://lodz.onet.pl/">
#            Łódź
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://poznan.onet.pl/">
#            Poznań
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://slask.onet.pl/">
#            Śląsk
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://wroclaw.onet.pl/">
#            Wrocław
#           </a>
#          </div>
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://kielce.onet.pl/">
#            Kielce
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://lublin.onet.pl/">
#            Lublin
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://olsztyn.onet.pl/">
#            Olsztyn
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://rzeszow.onet.pl/">
#            Rzeszów
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://trojmiasto.onet.pl/">
#            Trójmiasto
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://wbi.onet.pl/">
#            W. Brytania i Irlandia
#           </a>
#          </div>
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://krakow.onet.pl/">
#            Kraków
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://lubuskie.onet.pl/">
#            Lubuskie
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://opole.onet.pl/">
#            Opole
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://szczecin.onet.pl/">
#            Szczecin
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://warszawa.onet.pl/">
#            Warszawa
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="Menu_navMenuListItem__IRxhU">
#         <a class="Menu_navMenuLink__Qde0X" data-staticr="skip" href="https://pogoda.onet.pl/">
#          Pogoda
#          <span class="Menu_moreArrow__VYHyj">
#          </span>
#         </a>
#         <div class="Menu_subMenu__YLGLv CollapsedItems_collapsedMenu__l_XFH CollapsedItems_hidden__M8QZm" style="transform: translate(0px, 0);">
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/warszawa-357732">
#            Pogoda Warszawa
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/szczecin-351892">
#            Pogoda Szczecin
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/bialystok-270085">
#            Pogoda Białystok
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/dlugoterminowa/warszawa-357732">
#            Pogoda długoterminowa Warszawa
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/dlugoterminowa/lublin-311624">
#            Pogoda długoterminowa Lublin
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/dlugoterminowa/bydgoszcz-276560">
#            Pogoda długoterminowa Bydgoszcz
#           </a>
#          </div>
#          <div class="CollapsedItems_column__EyeRi">
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/wroclaw-362450">
#            Pogoda Wrocław
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/gdansk-287788">
#            Pogoda Gdańsk
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/lodz-313660">
#            Pogoda Łódź
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/dlugoterminowa/krakow-306020">
#            Pogoda długoterminowa Kraków
#           </a>
#           <a class="CollapsedItem_itemLinkSimple__i5zoz" data-staticr="skip" href="https://pogoda.onet.pl/prognoza-pogody/dlugoterminowa/zakopane-365801">
#            Pogoda długoterminowa Zakopane
#           </a>
# ...
#        </div>
#       </div>
#       <section class="StandardRightFeed_standardRightFeedContainer__S6Zwa undefined" data-section="nieruchomosci">
#        <h2 class="SectionTitle_sectionTitle__WTUrW SectionTItleSpotlight_yellow__Z2L9j SectionTitleVariant_standard__bBxha SectionTItleTheme_borderStandard__6qpJH" title="Nieruchomości">
#         <span class="SectionTitle_titleText__bXKXt SectionTitle_titleTextWithImage__ifaRi SectionTitle_imageOnRight__Vqw1P">
#          Nieruchomości
#          <a href="https://www.morizon.pl/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=partnership" rel="noreferrer" target="_blank">
#           <img alt="" class="Image_image__EUPoV SectionTitle_SponsorImage__JPKgE" height="24" loading="lazy" src="https://ocdn.eu/onetmobilemainpage/mainpage_desktop/logo/partner_morizon.svg"/>
#          </a>
#         </span>
#        </h2>
#        <article class="SmallCard_smallCard__UN_eb SmallCard_bottomLine__1aYLv">
#         <a class="SmallCard_smallCardLink__FW9JN SectionLink_linkStyle__m_glG" data-gtm="nieruchomosci_1" href="https://www.morizon.pl/mieszkania/najnowsze/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=listing-m" rel="noopener" target="">
#          <img alt="" class="Image_image__EUPoV SmallCard_smallCardImage__15Pr7" height="59" loading="lazy" src="https://ocdn.eu/omp3-images-transforms/1/Qe5k9lBaHR0cHM6Ly9vY2RuLmV1L3B1bHNjbXMvTURBXy9lODM5Y2I3YTE0NGJlMDcyZWExNjQ5ZWY1Y2MwMDc5ZC5qcGeSlQMAPc0D6M0CNJMFzF873gABoTAB" width="95"/>
#          <h3 class="TitleWrapper_titleWrapper__1v73l SmallCard_smallCardTitle__x7IRD">
#           Mieszkania na sprzedaż - sprawdź najnowsze oferty z całej Polski
#          </h3>
#         </a>
#        </article>
#        <article class="SmallCard_smallCard__UN_eb SmallCard_bottomLine__1aYLv">
#         <a class="SmallCard_smallCardLink__FW9JN SectionLink_linkStyle__m_glG" data-gtm="nieruchomosci_2" href="https://www.morizon.pl/blog/kiedy-zarobisz-na-kawalerke/?utm_source=rasp&amp;utm_medium=onet-widget-hp&amp;utm_campaign=kawalerka" rel="noopener" target="">
#          <img alt="" class="Image_image__EUPoV SmallCard_smallCardImage__15Pr7" height="59" loading="lazy" src="https://ocdn.eu/omp3-images-transforms/1/FVPk9lBaHR0cHM6Ly9vY2RuLmV1L3B1bHNjbXMvTURBXy85YjY1MTM0OTU1NWE0NWU0Y2E0NmFmNjc2ZWY2NWFiNy5qcGeSlQMAzQE8zRdwzQ0vkwXMXzveAAGhMAE" width="95"/>
#          <h3 class="TitleWrapper_titleWrapper__1v73l SmallCard_smallCardTitle__x7IRD">
#           Kawalerka - ile teraz kosztuje?
#          </h3>
#         </a>
#        </article>
#        <article class="SmallCard_smallCard__UN_eb SmallCard_bottomLine__1aYLv">
#         <a class="SmallCard_smallCardLink__FW9JN SectionLink_linkStyle__m_glG" data-gtm="nieruchomosci_3" href="https://www.morizon.pl/blog/dofinansowanie-do-mieszkania/?utm_source=rasp&amp;utm_medium=onet-widget-hp&amp;utm_campaign=dofinansowanie-mieszkanie" rel="noopener" target="">
#          <img alt="" class="Image_image__EUPoV SmallCard_smallCardImage__15Pr7" height="59" loading="lazy" src="https://ocdn.eu/omp3-images-transforms/1/35Kk9lBaHR0cHM6Ly9vY2RuLmV1L3B1bHNjbXMvTURBXy9kOGE2NTUxMThjMDRmYzAzYzM3NzIwMDViZmUzOWE3MC5qcGeSlQMAzFPNA-jNAjKTBcxfO94AAaEwAQ" width="95"/>
#          <h3 class="TitleWrapper_titleWrapper__1v73l SmallCard_smallCardTitle__x7IRD">
#           Dofinansowanie do mieszkania. Z jakiego wsparcia można skorzystać i kiedy?
#          </h3>
#         </a>
#        </article>
#        <article class="SmallCard_smallCard__UN_eb">
#         <a class="SmallCard_smallCardLink__FW9JN SectionLink_linkStyle__m_glG" data-gtm="nieruchomosci_4" href="https://www.morizon.pl/domy/najnowsze/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=listing-domy" rel="noopener" target="">
#          <img alt="" class="Image_image__EUPoV SmallCard_smallCardImage__15Pr7" height="59" loading="lazy" src="https://ocdn.eu/omp3-images-transforms/1/xank9lBaHR0cHM6Ly9vY2RuLmV1L3B1bHNjbXMvTURBXy82NDcyYjRhMDE0MzE0Zjk2ZDMwZjNkOThkMWYwNGMxMC5qcGeSlQMAzIbNA-jNAjOTBcxfO94AAaEwAQ" width="95"/>
#          <h3 class="TitleWrapper_titleWrapper__1v73l SmallCard_smallCardTitle__x7IRD">
#           Domy na sprzedaż - sprawdź najnowsze oferty z całej Polski
#          </h3>
#         </a>
#        </article>
#        <div class="StandardRightFeed_othersWrap__aQxc2">
#         <div class="NamedSectionLinks_namedSectionLinks__i2end StandardRightFeed_others___DWxG" data-testid="NamedSectionLinks">
#          <div class="NamedSectionLinks_title__jAWJL">
#           Więcej:
#          </div>
#          <div class="NamedSectionLinks_list__UzKUs">
#           <a class="NamedSectionLinks_link__cCIG_" data-testid="NamedSectionLinksA" href="https://www.morizon.pl/mieszkania/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=more">
#            Mieszkania
#           </a>
#           <a class="NamedSectionLinks_link__cCIG_" data-testid="NamedSectionLinksA" href="https://www.morizon.pl/domy/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=more">
#            Domy
#           </a>
#           <a class="NamedSectionLinks_link__cCIG_" data-testid="NamedSectionLinksA" href="https://www.morizon.pl/dzialki/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=more">
#            Działki
#           </a>
#           <a class="NamedSectionLinks_link__cCIG_" data-testid="NamedSectionLinksA" href="https://www.morizon.pl/do-wynajecia/komercyjne/biura/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=more">
#            Biura
#           </a>
#           <a class="NamedSectionLinks_link__cCIG_" data-testid="NamedSectionLinksA" href="https://www.morizon.pl/do-wynajecia/komercyjne/lokale-uzytkowe/?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=more">
#            Lokale użytkowe
#           </a>
#           <a class="NamedSectionLinks_link__cCIG_" data-testid="NamedSectionLinksA" href="https://www.morizon.pl/nieruchomosci/?ps%5Bowner%5D%5B0%5D=2&amp;utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=more">
#            Oferty deweloperów
#           </a>
#           <a class="NamedSectionLinks_link__cCIG_ NamedSectionLinks_linkLast__ucX6U" data-testid="NamedSectionLinksA" href="https://www.morizon.pl/zgloszenie?utm_source=Onet-RASP&amp;utm_medium=link&amp;utm_campaign=sidebar&amp;utm_content=more">
#            Sprzedaj nieruchomość
#           </a>
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <div data-name="bot_stop" data-pagetype="container">
#     </div>
#    </div>
#    <div class="Home_Grid__l6NSK">
#     <div class="SeoLinks_seoLinks__dYDJ9" data-screening-sticky-end="true" data-section="servicelist">
#      <h3 class="SeoLinks_title__jdaKM">
#       <a class="SeoLinks_titleLink__7K7Fm" href="">
#        Pogoda
#       </a>
#      </h3>
#      <div class="SeoLinks_linksWrapper__yK6Mt">
#       <a class="SeoLinks_linkItem__FWUBS" href="https://fajnegotowanie.pl/">
#        Fajne Gotowanie
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/">
#        Zapytaj
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Zadania/sciagi/index.html">
#        Ściągi
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/encyklopedia/index.html">
#        Encyklopedia
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Zadania/testy/index.html">
#        Testy szkolne
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Zadania/zadania/index.html">
#        Zadania szkolne
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/quizy/index.html">
#        Quizy
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Category/005/1,Biznes_i_Finanse.html">
#        Biznes i finanse
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Category/029/1,Gry.html">
#        Gry
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Category/028/1,Hobby.html">
#        Hobby
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Category/016/1,Jedzenie_i_Napoje.html">
#        Jedzenie i napoje
#       </a>
#       <a class="SeoLinks_linkItem__FWUBS" href="https://zapytaj.onet.pl/Category/021/1,Dla_Doroslych.html">
#        Dla dorosłych
#       </a>
#      </div>
#      <a class="SeoLinks_linkItem__FWUBS" href="">
#       więcej »
#      </a>
#     </div>
#     <footer class="Footer_pageFooter__mFL01" data-section="footer">
#      <a class="Footer_logoLink__X22EA" href="https://www.onet.pl">
#       <svg height="100%" viewBox="0 0 77 24" width="100%">
#        <path class="logo-cls-1" d="M50.315,89.332a6.345,6.345,0,1,1,6.4-6.344,6.291,6.291,0,0,1-6.4,6.344m0-9.6a3.258,3.258,0,1,0,3.225,3.258,3.124,3.124,0,0,0-3.225-3.258M66.217,89V82.009a2.187,2.187,0,0,0-2.337-2.422,2.892,2.892,0,0,0-2.6,1.663V89H58.105V77h2.777V78.23a5.009,5.009,0,0,1,3.934-1.586,4.468,4.468,0,0,1,3.25,1.293,5.155,5.155,0,0,1,1.325,3.691V89H66.217Zm23.611,0.21a4.277,4.277,0,0,1-3.139-1.03,4.077,4.077,0,0,1-1-3.022V79.994H83.7V77h1.984V74.2l3.174-.751V77H92v3H88.86v5.2c0,0.47.272,1.069,1.566,1.069,0.568,0,1.542-.119,1.542-0.119v2.816a10.862,10.862,0,0,1-2.14.247M77.4,89.332c-3.895,0-6.615-2.609-6.615-6.345a6.244,6.244,0,1,1,12.486,0,7.048,7.048,0,0,1-.121,1.274l-0.006.031H74.112a3.115,3.115,0,0,0,3.333,2.168,3.351,3.351,0,0,0,2.527-1.023l2.6,1.441a6.119,6.119,0,0,1-5.18,2.453m2.687-7.506a2.864,2.864,0,0,0-2.927-2.334,2.96,2.96,0,0,0-3.095,2.334h6.022Z" style="fill: #1e1e1e;" transform="translate(-15 -71)">
#        </path>
#        <path class="logo-cls-2" d="M39.117,83A12.059,12.059,0,1,1,27.058,71,12.029,12.029,0,0,1,39.117,83" style="fill: #ffd200;" transform="translate(-15 -71)">
#        </path>
#       </svg>
#      </a>
#      <div class="Footer_footerMenu__uwsb_">
#       <a class="Footer_footerMenuItem__E3SB2" href="https://www.onet.pl/serwisy">
#        Mapa serwisów
#       </a>
#       <a class="Footer_footerMenuItem__E3SB2" href="https://polityka-prywatnosci.onet.pl/">
#        Prywatność
#       </a>
#       <a class="Footer_footerMenuItem__E3SB2" href="https://reklama.ringieraxelspringer.pl/">
#        Reklama
#       </a>
#       <a class="Footer_footerMenuItemLast__fNoYx" href="https://www.ringieraxelspringer.pl/kariera/oferty-pracy/">
#        Praca w Onecie
#       </a>
#      </div>
#      <div class="Footer_copyright__NqLnN">
#       © 2022 Ringier Axel Springer Polska sp. z o.o. - Powered by
#       <a class="Footer_copyrightLink__26llJ" href="https://ringpublishing.com/">
#        Ring Publishing
#       </a>
#       | Developed by
#       <a class="Footer_copyrightLink__26llJ" href="https://tech.ringieraxelspringer.com/">
#        RAS Tech
#       </a>
#      </div>
#     </footer>
#    </div>
#    <div class="onet-ad" data-autoslot="0" data-section="ad-layer" id="onet-ad-layer">
#    </div>
#    <div class="onet-ad" data-autoslot="0" data-section="ad-flat-belkadolna" id="onet-ad-flat-belkadolna">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"siteConfiguration":{"ads":{"target":"GLOWNA/NOWASG","dv":"www","DV":"www","adsNoBanner":false,"gemius":"bPo6D0bzSxcue3osfkZZIJaE.l0RyeOgSEhsufRYys3.W7","no_gemius":1,"kropka":{"DG":"id=bPo6D0bzSxcue3osfkZZIJaE.l0RyeOgSEhsufRYys3.W7","DC":"BETA","XX":"dev-env","NA":null},"keywords":["V2021","ONET3D_2I","ONET3"],"lazy":true,"lazyPercentage":150,"mobile":0,"async":1,"cmd":[]},"emergencyPlayer":{"title":"","url":""},"videoSettings":{"pulse2EmbedCfg":{"preset":"mainVideo","player":"flowplayer"}},"main":{"description":"Onet: codzienne źródło informacji milionów Polaków - wiadomości z kraju i ze świata 24/7, pogoda, sport, biznes, moto, rozrywka. Bądź na bieżąco z Onet!","emotions":{"emotions":{"emotion_1":{"text":"Lubię to","children":[],"code":"emotion_1","title":"Lubię to","url":"https://ocdn.eu/onetmobilemainpage/emotion/svg/1.svg","enabled":"on"},"emotion_4":{"text":"Ważne","children":[],"code":"emotion_4","title":"Ważne","url":"https://ocdn.eu/onetmobilemainpage/emotion/svg/4.svg","enabled":"on"},"emotion_5":{"text":"Wesołe","children":[],"code":"emotion_5","title":"Wesołe","url":"https://ocdn.eu/onetmobilemainpage/emotion/svg/5.svg","enabled":"on"},"emotion_3":{"text":"Smutne","children":[],"code":"emotion_3","title":"Smutne","url":"https://ocdn.eu/onetmobilemainpage/emotion/svg/3.svg","enabled":"on"},"emotion_2":{"text":"Wkurzony","children":[],"code":"emotion_2","title":"Wkurzony","url":"https://ocdn.eu/onetmobilemainpage/emotion/svg/2.svg","enabled":"on"},"emotion_6":{"text":"Nie lubię","children":[],"code":"emotion_6","title":"Nie lubię","url":"https://ocdn.eu/onetmobilemainpage/emotion/svg/6.svg","enabled":"on"}},"emotionsOrder":["emotion_1","emotion_4","emotion_5","emotion_3","emotion_2","emotion_6"]},"emotionsOn":true,"isPremium":false,"isBrandPage":false,"nonInstantInNewTab":true,"nonInstantInNewTabDesktop":false,"observerRootMarginDesktop":"1500","observerRootMarginMobile":"1500","phoenixNamespaces":["jVOQR1505835440665","TfsuA1562566747336","LUNMR1506925289107","xvTpp1582706639996","pJvAg1559811532389","xbFzt1582705866635","vXrFL1562569434694","LmdIo1583392632447","BQhSg1595589866796","oAmqF1566379821222","TXMaH1570713971176","FEAZt1571308007910"," JctpE1620896095566","frTyS1571736769901","vkGgc1555504918950","zrWCk1555502458742","NeDCc1628689477980","yaxea1591191911550","TuTkT1651064667656"],"phoenixOn":true,"title":"Onet – Jesteś na bieżąco ","leopardInImportantNews":true,"enablePulsevideoOnList":true,"forcePersonalizationFallback":false},"onboarding":{"enabled":true,"pvCapping":2,"list":[{"id":"onboarding-save-for-later-detal","title":"\"Zapisz na później\"","description":"Aby zapisać artykuł na później, kliknij w guzik \"Zapisz\" z ikoną zakładki","query":"#detail [data-onboarding=save-for-later]","index":0,"stickToElement":false,"available":false,"capping":{"seconds":0,"minutes":0,"hours":0,"days":2}},{"id":"onboarding-save-for-later-sg","title":"\"Zapisz na później\"","description":"Aby zapisać artykuł na później, kliknij w guzik \"Zapisz\" z ikoną zakładki","query":"#__next:not([aria-hidden=true]) [data-pagetype=page] [data-onboarding=save-for-later]","index":2,"stickToElement":false,"available":true,"capping":{"seconds":0,"minutes":0,"hours":0,"days":7}},{"id":"onboarding-header-profile-icon","title":"\"Zapisane materiały\"","description":"Tutaj znajdziesz materiały zapisane na później i obserwowanych autorów","query":"body [data-onboarding=header-profile-icon]","index":0,"stickToElement":"on","available":true,"capping":{"seconds":0,"minutes":0,"hours":0,"days":7}},{"id":"onboarding-swipe","title":"\"Następny artykuł\"","description":"Kliknij strzałkę lub przesuń palcem po ekranie, aby zobaczyć kolejny artykuł.","query":"body [data-onboarding=swipe-dots]","index":0,"stickToElement":"on","available":true,"capping":{"seconds":0,"minutes":0,"hours":0,"days":2}},{"id":"onboarding-watch-authors","title":"Obserwuj autorów","description":"Aby widzieć najnowsze publikacje ulubionego autora, ...
#   </script>
#   <div id="__phx_modal">
#   </div>
#   <div id="__bottomBanner">
#   </div>
#   <div id="__profileFormLayer">
#   </div>
#   <script>
#    window.addEventListener('load', function()  {
#     const logo = document.querySelector('.onetLogo');
#
#     if (onetAds.DV.indexOf("M_GLOWNA") > -1  && logo && logo.getAttribute('href').indexOf('https://csr.onet.pl') > -1) {
#         logo.setAttribute('target', '_blank');
#     }
# });
#   (function(){
#     if(document.location && document.location.search && (document.location.search.indexOf('utm_medium=pushpushgo') > -1)) {
#         var d = new Date();
#         d.setTime(d.getTime() + (15*60*1000));
#         var expires = "expires="+ d.toUTCString();
#         var cvalue = +new Date();
#         document.cookie = "onet_push_ts=" + cvalue + ";" + expires + ";path=/";
#     }
#     })();
#   </script>
#  </body>
# </html>

# %%
#scrappujemy dane
import requests
from bs4 import BeautifulSoup
   
url = "https://www.filmweb.pl/film/Narodziny+gwiazdy-2018-542576"
r = requests.get(url)
   
soup = BeautifulSoup(r.content, 'html5lib')
   
table = soup.findAll('a') #szukamy wszystkich tagów z atrybutem 'a' czyli donosniki do innych źródeł/stron

print("Na analizowanej stronie znaleziono: " + str(len(table)) + " odnośników")
# Out:
# Na analizowanej stronie znaleziono: 303 odnośników

# %%
#sprawdźmy ilość odnośników na różnych portalach informacyjnych
# tym celu utworzmy funkcje i wywołajmy ją dla różnych serwisów informacyjnych
def linki(url):
    r = requests.get(url)
   
    soup = BeautifulSoup(r.content, 'html5lib')
   
    table = soup.findAll('a')

    print(f"Na stronie: {url} znaleziono: " + str(len(table)) + " odnośników")

# %%
linki('https://www.onet.pl/')
linki('https://www.wp.pl/')
linki('https://www.interia.pl/')
linki('https://www.cnn.com/')
linki('https://www.bbc.com/')
linki('https://www.foxnews.com/')
# Out:
# Na stronie: https://www.onet.pl/ znaleziono: 492 odnośników
# Na stronie: https://www.wp.pl/ znaleziono: 275 odnośników
# Na stronie: https://www.interia.pl/ znaleziono: 500 odnośników
# Na stronie: https://www.cnn.com/ znaleziono: 233 odnośników
# Na stronie: https://www.bbc.com/ znaleziono: 291 odnośników
# Na stronie: https://www.foxnews.com/ znaleziono: 837 odnośników

# %% [markdown]
# <b>Zagadnienie</b>: chcemy sprawdzić, ile jest ogłoszeń pracy dla różnych typów stanowisk w obszarze danych. Chcemy pobrać dane i zwizualizować.

# %%
#Sprawdzmy stanowiska dla osob szukajacych pracy w obszarze danych

import requests
from bs4 import BeautifulSoup
   
url = "https://nofluffjobs.com/pl/Data?page=1"
r = requests.get(url)
   
soup = BeautifulSoup(r.content, 'html5lib')
   
table = soup.findAll('h3', class_="posting-title__position text-truncate color-main ng-star-inserted")#, _ngcontent-sc450="")

# %%
#pobieramy tylko nazwy stanowisk
lista_ogloszen = []
for poz in table:
    lista_ogloszen.append(poz.get_text().strip()) #get_text() pobiera wartość tekstową bloku
lista_ogloszen
# Out:
# ['Data Engineer',
#  'Java Software Engineer',
#  'Senior Data Engineer (Python/Scala, AWS)',
#  'Data Engineer',
#  'Remote Senior Java Backend Developer',
#  'Data Engineer',
#  'Senior Data Engineer (freelance)',
#  'Data Analytics Engineer',
#  'Data Engineer',
#  'Mid Data Analyst BI Developer',
#  'Data Architect',
#  'Lead Big Data Engineer (Python + Spark)',
#  'Remote Senior Java Backend Developer',
#  'Data Integration / Processing Engineer',
#  'Cloud & Big data Architect',
#  'DataOPS / Data Analyst',
#  'Data Engineer - 100% remote',
#  'Senior ETL Developer',
#  'Product Manager',
#  'Remote Senior Data Engineer with AWS']

# %%
#zróbmy to samo w formie funkcji
def scrapping(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html5lib')
    table = soup.findAll('h3', class_="posting-title__position text-truncate color-main ng-star-inserted")#, _ngcontent-sc450="") 
    for poz in table:
        lista_ogloszen.append(poz.get_text().strip())
    return lista_ogloszen

# %%
#utwórzmy funkcje do sprawdzenia wielu stron do przeszukania
def strony_do_przeszukania(url):
    pages = soup.findAll('a', class_="page-link")
    lista_stron = []
    for strona in range(1,int(pages[-2].get_text().strip())+1):
        lista_stron.append(url[:-1]+str(strona))
    return lista_stron

# %%
url = "https://nofluffjobs.com/pl/Data?page=1"
lista_ogloszen = []
pelna_lista_nazw = []
def przeszukaj_wszystkie_strony(url, lista_ogloszen, pelna_lista_nazw):
    lista_stron = strony_do_przeszukania(url)
    for url in lista_stron:
        scrapping(url)
    return lista_ogloszen
finalna_lista_ogłoszeń = przeszukaj_wszystkie_strony(url, lista_ogloszen, pelna_lista_nazw)

# %%
#funkcja do zliczania wystąpień na liście
from collections import Counter
count = dict(Counter(finalna_lista_ogłoszeń))

#przekształcamy słownik do formy pożądanej przez DataFrame (słownik list)
pozycja = []
ilosc = []
for k, v in count.items():
    pozycja.append(k)
    ilosc.append(v)
zliczenie = {"pozycja":pozycja, "ilosc":ilosc}

# %%
#wyświetlmy dane
import matplotlib.pyplot as plt
import pandas as pd
df = pd.DataFrame(zliczenie)
df = df[df.ilosc > 1].sort_values(by = ['ilosc'], ascending = False) #filtrujemy i sortujemy
plt.figure(figsize= (20,7)) #zmieniamy wymiar wykresu
plt.bar(df.pozycja, df.ilosc, color='red')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Zadanie - możemy spróbować pobrać wynagrodzenia
